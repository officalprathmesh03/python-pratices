# %%
# !pip install openpyxl

# %%
# !pip install pandas

# %%
import pandas as pd
import numpy as np

# %%
data = [10, 20, 30, 40] # this is a list
series = pd.Series(data)
print(series)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# dtype: int64

# %%
import pandas as pd  # Import the pandas library
#df = pd.read_csv(r"D:\download\NMD\python\DA 11\DA11 python\car_sales_india.csv")
df = pd.read_csv(r"D:\download\NMD\python\DA 11\DA11 python\car_sales_india.csv") # Read the CSV file into a DataFrame
print(df.head(10))
# Out:
#    Sale ID        Date Car Brand Car Model Fuel Type Transmission  \
# 0        1  2023-07-28     Honda     Amaze  Electric    Automatic
# 1        2  2023-07-30  Mahindra      Thar    Diesel       Manual
# 2        3  2023-07-30     Honda      City  Electric    Automatic
# 3        4  2023-02-12      Tata     Tiago  Electric    Automatic
# 4        5  2023-02-27     Honda     Amaze  Electric       Manual
# 5        6  2023-09-12     Honda      City    Diesel       Manual
# 6        7  2023-04-09     Honda     Amaze  Electric    Automatic
# 7        8  2023-01-24   Hyundai       i10  Electric       Manual
# 8        9  2023-07-07     Honda      Jazz    Petrol    Automatic
# 9       10  2023-01-24  Mahindra   Scorpio  Electric    Automatic
#
#    Price (INR)       City Seller Type  Year of Manufacture  Mileage (km/l)  \
# 0      2636520    Chennai  Individual                 2018            19.6
# 1      1067639     Mumbai      Dealer                 2022            17.3
# ...

# %%
df.tail()  # last 5 data
# Out:
#      Sale ID        Date Car Brand Car Model Fuel Type Transmission  \
# 495      496  2023-12-03   Hyundai     Verna       CNG    Automatic
# 496      497  2023-01-13   Hyundai       i10    Petrol    Automatic
# 497      498  2023-03-12      Tata   Harrier  Electric    Automatic
# 498      499  2023-12-21   Hyundai     Creta    Petrol    Automatic
# 499      500  2023-11-20    Maruti     Dzire  Electric    Automatic
#
#      Price (INR)       City Seller Type  Year of Manufacture  Mileage (km/l)  \
# 495      1798782     Mumbai      Dealer                 2020            23.4
# 496       505073  Hyderabad      Dealer                 2016            11.1
# 497      1459012  Hyderabad      Dealer                 2015            12.7
# 498      2512166  Hyderabad  Individual                 2020            13.1
# 499       977102  Hyderabad      Dealer                 2016            13.3
#
#      Engine Capacity (cc)
# 495                  1500
# 496                  1800
# ...

# %%
df.info()   # give info about data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Sale ID               500 non-null    int64
#  1   Date                  500 non-null    object
#  2   Car Brand             500 non-null    object
#  3   Car Model             500 non-null    object
#  4   Fuel Type             500 non-null    object
#  5   Transmission          500 non-null    object
#  6   Price (INR)           500 non-null    int64
#  7   City                  500 non-null    object
#  8   Seller Type           500 non-null    object
#  9   Year of Manufacture   500 non-null    int64
#  10  Mileage (km/l)        500 non-null    float64
#  11  Engine Capacity (cc)  500 non-null    int64
# dtypes: float64(1), int64(4), object(7)
# memory usage: 47.0+ KB

# %%
df.describe()  # its give summary od mathematical data
# Out:
#           Sale ID   Price (INR)  Year of Manufacture  Mileage (km/l)  \
# count  500.000000  5.000000e+02           500.000000      500.000000
# mean   250.500000  1.715120e+06          2019.066000       17.303400
# std    144.481833  8.084176e+05             2.622097        4.250805
# min      1.000000  3.065960e+05          2015.000000       10.000000
# 25%    125.750000  9.786890e+05          2017.000000       13.500000
# 50%    250.500000  1.765048e+06          2019.000000       17.200000
# 75%    375.250000  2.465958e+06          2021.000000       21.100000
# max    500.000000  2.998496e+06          2023.000000       25.000000
#
#        Engine Capacity (cc)
# count             500.00000
# mean             1671.60000
# std               502.25288
# min              1000.00000
# 25%              1200.00000
# 50%              1500.00000
# 75%              2000.00000
# max              2500.00000

# %%
df.isnull().sum()  # its  give  sum of null value
# Out:
# Sale ID                 0
# Date                    0
# Car Brand               0
# Car Model               0
# Fuel Type               0
# Transmission            0
# Price (INR)             0
# City                    0
# Seller Type             0
# Year of Manufacture     0
# Mileage (km/l)          0
# Engine Capacity (cc)    0
# dtype: int64

# %%
d= d.drop_duplicates() #
print(d)
# Out:
#         ID          Name           Age       Location            Join Date  \
# 0        1          Mike            35       New York  2020-06-05 00:00:00
# 1        2         Sarah            29       New York  2021-05-12 00:00:00
# 2        3  Not Avalible           NaN        Chennai  2020-06-05 00:00:00
# 3        4       Jane D.            29          Delhi  2021-05-12 00:00:00
# 4        5         John             25  Mumbai, India  2021-05-12 00:00:00
# ...    ...           ...           ...            ...                  ...
# 9595  9596         John             25         London  2020-06-05 00:00:00
# 9596  9597  Not Avalible  Not Avalible         London  2023-07-07 00:00:00
# 9597  9598  Not Avalible            35       New York  2021-07-11 00:00:00
# 9598  9599          Mike            30      Bangalore  2023-05-06 00:00:00
# 9599  9600         Sarah  Not Avalible        Chennai  2023-07-07 00:00:00
#
# ...

# %%
# Sample data as a dictionary
data = {
    "Name": ["Alice", "Bob", "Charlie"],
    "Age": [25, 30, 35],
    "City": ["New York", "Los Angeles", "Chicago"]
}
# Create a DataFrame from the dictionary
df = pd.DataFrame(data)
df
# Out:
#       Name  Age         City
# 0    Alice   25     New York
# 1      Bob   30  Los Angeles
# 2  Charlie   35      Chicago

# %%
df.to_csv("hi.csv") # its data store in csv file

# %%
import pandas as pd
d = pd.read_excel(r"D:\download\NMD\python\DA 11\DA11 python\Practice_sheet unclean.xlsx")
print(d.head(100))
# Out:
#      ID          Name           Age       Location            Join Date  \
# 0     1          Mike            35       New York  2020-06-05 00:00:00
# 1     2         Sarah            29       New York  2021-05-12 00:00:00
# 2     3  Not Avalible           NaN        Chennai  2020-06-05 00:00:00
# 3     4       Jane D.            29          Delhi  2021-05-12 00:00:00
# 4     5         John             25  Mumbai, India  2021-05-12 00:00:00
# ..  ...           ...           ...            ...                  ...
# 95   96          John  Not Avalible         London  2021-07-11 00:00:00
# 96   97          John            25       New York  2021-05-12 00:00:00
# 97   98          John  Not Avalible       New York  2022-11-01 00:00:00
# 98   99       Jane D.  Not Avalible          Delhi  2021-05-12 00:00:00
# 99  100          Sara  Not Avalible         London  2020-06-05 00:00:00
#
#           Salary      Department               Email         Phone  \
# ...

# %%
d.describe()
# Out:
#                 ID
# count  9600.000000
# mean   4800.500000
# std    2771.425626
# min       1.000000
# 25%    2400.750000
# 50%    4800.500000
# 75%    7200.250000
# max    9600.000000

# %%
import pandas as pd  # Import the pandas library
df = pd.read_excel(r"D:\download\NMD\python\DA 11\DA11 python\Practice_sheet unclean.xlsx")
 # Read the CSV file into a DataFrame
print(df.head(10))
# Out:
#    ID          Name  Age       Location            Join Date        Salary  \
# 0   1          Mike   35       New York  2020-06-05 00:00:00         50000
# 1   2         Sarah   29       New York  2021-05-12 00:00:00         45000
# 2   3  Not Avalible  NaN        Chennai  2020-06-05 00:00:00  Not Avalible
# 3   4       Jane D.   29          Delhi  2021-05-12 00:00:00         45000
# 4   5         John    25  Mumbai, India  2021-05-12 00:00:00         58000
# 5   6       Jane D.   40   Not Avalible  2023-06-05 00:00:00         52000
# 6   7          John   30  Mumbai, India  2020-06-05 00:00:00         45000
# 7   8  Not Avalible   29       New York  2021-07-11 00:00:00         52000
# 8   9          Mike   25      Bangalore  2021-05-12 00:00:00         45000
# 9  10          Mike   29         London  2021-05-12 00:00:00         45000
#
#        Department               Email         Phone    Experience  ...  \
# ...

# %%
import pandas as pd
import sqlite3

# Connect database
conn = sqlite3.connect("employees.db")

# Read SQL file

with open(r"D:\download\NMD\python\DA 11\DA11 python\employees Database.sql", "r") as file:
     sql_script = file.read()
     print(df.head())
# Out:
#    ID          Name  Age       Location            Join Date        Salary  \
# 0   1          Mike   35       New York  2020-06-05 00:00:00         50000
# 1   2         Sarah   29       New York  2021-05-12 00:00:00         45000
# 2   3  Not Avalible  NaN        Chennai  2020-06-05 00:00:00  Not Avalible
# 3   4       Jane D.   29          Delhi  2021-05-12 00:00:00         45000
# 4   5         John    25  Mumbai, India  2021-05-12 00:00:00         58000
#
#        Department               Email         Phone    Experience  ...  \
# 0              HR  jane.d@example.net    0000000000             3  ...
# 1       Marketing                 NaN    9876543210  Not Avalible  ...
# 2              HR    john@example.com  Not Avalible             3  ...
# 3              HR  jane.d@example.net    0000000000             5  ...
# 4  Human Resource        Not Avalible  Not Avalible             5  ...
#
#   Nationality   Has Vehicle  Vehicle Type   Blood Group        Height Weight  \
# ...
